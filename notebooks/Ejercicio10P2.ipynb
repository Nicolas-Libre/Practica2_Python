# %%
from src import FUNCIONESP2EJ10

# %%
rounds = [
{
    'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
    'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
    'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
    'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
    'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
    'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
    'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
    'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
    'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
    'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
},
{
    'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
    'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
    'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
    'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
    'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
    'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
    'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
    'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
    'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
    'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
    'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
    'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
    'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
    'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
    'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
}
]

#Se declara el diccionario de la ronda final, se le agregan los campos MVPS y points
ronda_final= {
    'Shadow': {'kills': 0, 'assists': 0, 'deaths': 0, 'MVP´s': 0, 'points': 0},
    'Blaze':{'kills': 0, 'assists': 0, 'deaths': 0, 'MVP´s': 0, 'points': 0},
    'Viper':{'kills': 0, 'assists': 0, 'deaths': 0, 'MVP´s': 0, 'points': 0},
    'Frost':{'kills': 0, 'assists': 0, 'deaths': 0, 'MVP´s': 0, 'points': 0},
    'Reaper':{'kills': 0, 'assists': 0, 'deaths': 0, 'MVP´s': 0, 'points': 0}
}

# Puntajes: 
# kill = 3 puntos 
# asistencia = 1 punto
# Muerte = -1 punto

#Listas usadas para imprimir strings, una para las rondas y otra para el final
lista_ronda = ['jugador','kills','assists','deaths','points']
lista_final = ['jugador','kills','assists','deaths','MVP´s','points']

for i, round in enumerate(rounds):
    print (f'Ronda = {i+1}')
    FUNCIONESP2EJ10.imprimir_ronda (lista_ronda)
    print('')
    print ('-------------------------------------------')
    #Para cada jugador en la ronda...
    for player in round:
        #Se le agregan los puntos en la ronda
        rounds[i]= FUNCIONESP2EJ10.agregar_puntos(round,player)

        #Se suman a la ronda final
        ronda_final[player]['kills'] += round[player]['kills']
        ronda_final[player]['assists'] += round[player]['assists']
        if round[player]['deaths'] == True:
            ronda_final[player]['deaths'] +=1
        ronda_final[player]['points'] += round[player]['points']
    
    #Se ordena la ronda para su impresion
    round = FUNCIONESP2EJ10.ordenar_ronda (round)
    FUNCIONESP2EJ10.imprimir_bien (round)
    
    #Se calcula el MVP, se agrega un int a la ronda final y se imprime quien fue
    MVP = FUNCIONESP2EJ10.calcular_MVP (round)
    ronda_final[MVP]['MVP´s'] +=1
    
    print('')
    print (f'El MVP de la ronda es {MVP}')
    print('-----------------------------')
    print('')
#Luego de immprimir cada ronda, se imprime el resumen de todas las rondas (Ronda Final)
print ('Ronda Final:')
#La lista final, solo se utiliza para imprimir
FUNCIONESP2EJ10.imprimir_final(ronda_final, lista_final)
# Out:
# Ronda = 1
# Jugador   Kills   Assists   Deaths   Points
# -------------------------------------------
# Shadow      2        1        1        6
# Viper       1        2        1        4
# Reaper      1        1        0        4
# Blaze       1        0        0        3
# Frost       0        1        0        1
#
# El MVP de la ronda es Shadow
# -----------------------------
#
# Ronda = 2
# Jugador   Kills   Assists   Deaths   Points
# -------------------------------------------
# Frost       2        1        1        6
# Blaze       2        0        1        5
# Viper       1        1        0        4
# Shadow      0        2        0        2
# Reaper      0        1        0        1
#
# El MVP de la ronda es Frost
# -----------------------------
#
# Ronda = 3
# Jugador   Kills   Assists   Deaths   Points
# -------------------------------------------
# Blaze       2        2        1        7
# Reaper      1        1        0        4
# ...
